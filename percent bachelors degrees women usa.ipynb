# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('percent_bachelors_degrees_women_usa.csv')

# %%
df.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439  \
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering
# 0                           35.3              13.6  74.535328          0.8  \
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           45 non-null     int64
#  1   Agriculture                    45 non-null     float64
#  2   Architecture                   45 non-null     float64
#  3   Art and Performance            45 non-null     float64
#  4   Biology                        45 non-null     float64
#  5   Business                       45 non-null     float64
#  6   Communications and Journalism  45 non-null     float64
#  7   Computer Science               45 non-null     float64
#  8   Education                      45 non-null     float64
#  9   Engineering                    45 non-null     float64
#  10  English                        45 non-null     float64
#  11  Foreign Languages              45 non-null     float64
# ...

# %%
if df.duplicated().sum() > 0:
    print ("Yes, dublicates exists")
else:
    print("No dublicates")
# Out:
# Yes, dublicates exists

# %%
df1 = df.drop_duplicates()

# %%
print (df1)
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology
# 0   1970     4.229798     11.921005                 59.7  29.088363  \
# 1   1971     5.452797     12.003106                 59.9  29.394403
# 2   1972     7.420710     13.214594                 60.4  29.810221
# 3   1973     9.653602     14.791613                 60.2  31.147915
# 4   1974    14.074623     17.444688                 61.9  32.996183
# 5   1975    18.333162     19.134048                 60.9  34.449902
# 6   1976    22.252760     21.394491                 61.3  36.072871
# 7   1977    24.640177     23.740541                 62.0  38.331386
# 8   1978    27.146192     25.849240                 62.5  40.112496
# 9   1979    29.633365     27.770477                 63.2  42.065551
# 10  1980    30.759390     28.080381                 63.4  43.999257
# 11  1981    31.318655     29.841694                 63.3  45.249512
# 12  1982    32.636664     34.816248                 63.1  45.967338
# ...

# %%
if df1.duplicated().sum() > 0:
    print ("Yes, dublicates exists")
else:
    print ("No dublicates")
# Out:
# No dublicates

# %%
df.head(25)
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology
# 0   1970     4.229798     11.921005                 59.7  29.088363  \
# 1   1971     5.452797     12.003106                 59.9  29.394403
# 2   1972     7.420710     13.214594                 60.4  29.810221
# 3   1973     9.653602     14.791613                 60.2  31.147915
# 4   1974    14.074623     17.444688                 61.9  32.996183
# 5   1975    18.333162     19.134048                 60.9  34.449902
# 6   1976    22.252760     21.394491                 61.3  36.072871
# 7   1977    24.640177     23.740541                 62.0  38.331386
# 8   1978    27.146192     25.849240                 62.5  40.112496
# 9   1979    29.633365     27.770477                 63.2  42.065551
# 10  1980    30.759390     28.080381                 63.4  43.999257
# 11  1981    31.318655     29.841694                 63.3  45.249512
# 12  1982    32.636664     34.816248                 63.1  45.967338
# ...

# %% [markdown]
# Knowing the style of the line in the Communications and Journalism over the years

# %%
plt.plot()

# %%
plt.plot(df1['Year'], df1['Communications and Journalism'], marker = '.', linestyle = '-')

# %%
plt.plot(df1['Year'], df1['Art and Performance'], marker = '.', linestyle = '-')

# %%
plt.plot(df1['Year'], df1['Computer Science'], marker = '.', linestyle = '-')

# %%
plt.plot(df1['Year'], df1['Education'], marker = '.', linestyle = '-')

# %%
plt.barh(df1['Year'], df1['Biology'])
# Out:
# <BarContainer object of 42 artists>

# %%
plt.plot(df1['Year'], df1['Architecture'], marker = '.', linestyle = '-')

# %%
plt.barh(df1['Year'], df1['Architecture'])
# Out:
# <BarContainer object of 42 artists>

# %%
plt.barh(df1['Year'], df1['Math and Statistics'])
# Out:
# <BarContainer object of 42 artists>

# %%
plt.plot(df1['Year'], df1['Math and Statistics'], marker = '.', linestyle = '-')
